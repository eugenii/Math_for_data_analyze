# %%
# Импорт библиотек
import numpy as np

# %%
# 1

t_celcii = np.array([167, 464, 15, -63, -145, -139, -197, -214])

t_farenheit = t_celcii * 9 / 5 + 32

print(t_farenheit)
# Out:
# [ 332.6  867.2   59.   -81.4 -229.  -218.2 -322.6 -353.2]

# %%
import numpy as np
obzor_list  = [7, 11, 10, 8, 4, 15, 15] # цены за обзорную экскурсию
museum_list = [0, 7, 8, 0, 6, 9, 10]    # цены за посещение музея
myths_list = [14, 0, 17, 0, 19, 18, 20] # мифы и легенды города
a = np.array(obzor_list)
b = np.array(museum_list)
c = np.array(myths_list)
o = 450 * a + 1300 * b + 750 * c
print(o)
# Out:
# [13650 14050 27650  3600 23850 31950 34750]

# %%
angle_degrees = 70
angle_radians = np.deg2rad(angle_degrees)
# print(angle_radians)
print(np.sin(angle_radians), np.cos(angle_radians), np.tan(angle_radians))
# Out:
# 0.9396926207859083 0.3420201433256688 2.7474774194546216

# %%
sin_alpha = -np.pi/4
cos_beta = np.pi/5

# Допишите код здесь
alpha_rad = np.arcsin(sin_alpha)
alpha_deg = np.rad2deg(alpha_rad)
beta_rad = np.arccos(cos_beta)
beta_deg = np.rad2deg(beta_rad)
print(alpha_deg, beta_deg) # Вывод значения углов альфа и бета
print(np.tan(alpha_rad)) # Вывод значения тангенса угла альфа
print(np.tan(beta_rad)) # Вывод значения тангенса угла бета
# Out:
# -51.75751851602197 51.07382455346838
# -1.2688363802786087
# 1.2381557216515395
