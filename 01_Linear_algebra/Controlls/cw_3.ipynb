# %%
# Импорты необходимых библиотек
import numpy as np

# %%
# Паровоз	Гладиатор	Дерзкие коты	Любители	Тарабаровск
# Значения представлены в коде ниже. 
# В отдельных строчках в таком же порядке выведите с помощью индексации:
# Данные о продажах формы «Дерзких котов».
# Продажи «Гладиатора» на второй неделе.
# Продажи «Тарабаровска» на 1 неделе.
# Данные о продажах 4 недели.

football = np.array([
        [12, 37, 48, 52, 40],
        [45, 20, 35, 80, 27],
        [16, 29, 33, 51, 42],
        [30, 44, 29, 38, 43],
        [71, 33, 25, 26, 40],
        [46, 54, 29, 38, 47],
    ])

import numpy as np

football = np.array([
        [12, 37, 48, 52, 40],
        [45, 20, 35, 80, 27],
        [16, 29, 33, 51, 42],
        [30, 44, 29, 38, 43],
        [71, 33, 25, 26, 40],
        [46, 54, 29, 38, 47],
])
print(football[:, 2])
print(football[2, 1])
print(football[1, 4])
print(football[4,:])
# Out:
# [48 35 33 29 25 29]
# 20
# 33
# [30 44 29 38 43]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 2

a = np.array([8, -3, 1, 6])
# Значения элементов матрицы C: 
C = np.array([
    [0, 6, -4, 2],
    [1, 8, 7, -12],
    [5, 0, -2, 8],
    [3, 8, 2, 4]
])

Z = np.array([
    [1, 1, -9, 4],
    [2, 8, 4, 6],
    [0, 8, 6, 0],
    [1, 5, -3, 4]
])
# Значения элементов матрицы M:
M = np.array([
   [2, 15, 1],
   [1, -7, 9],
   [3, 3, 7], 
   [0, 5, 12]
])
# допишите код здесь
print("Произведение Za:")
print(Z @ a.reshape(-1, 1))
print()
print("Произведение CM:")
print(C @ M)
print()
print("Произведение a^TM:")
print('no')
print()
print("Произведение CZ:")
print(C @ Z)
# Out:
# Произведение Za:
# [[ 20]
#  [ 32]
#  [-18]
#  [ 14]]
#
# Произведение CM:
# [[ -6 -44  50]
#  [ 31 -80 -22]
#  [  4 109  87]
#  [ 20  15 137]]
#
# Произведение a^TM:
# no
#
# Произведение CZ:
# [[ 14  26  -6  44]
#  [  5  61 101   4]
#  [ 13  29 -81  52]
#  [ 23 103   5  76]]

# %%
a = np.array([
    [2, -6],
    [4, 0.5]
])
b = np.linalg.inv(a)
print(b)
# Out:
# [[ 0.02  0.24]
#  [-0.16  0.08]]
