# %%
# imports

import numpy as np

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# lesson 1 ex 6

def y(x):
    return 2 * x - x ** 3

x = np.array([2, -3.5, 11])
print(y(x))
# Out:
# [   -4.       35.875 -1309.   ]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def y(x):
    return -2.5 * x ** 2 - 0.5 * x ** 3 + x ** 4 - x

x = np.arange(-5, 5, 1)
print(y(x))
# Out:
# [630. 252.  75.  12.   0.   0.  -3.   0.  42. 180.]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Используйте векторы из Numpy, чтобы считать сразу по всем ингредиентам.
import numpy as np 

# Функция для красивого вывода ингредиентов на экран.
def print_ingredients(ingredients):
	print("Яйца:", ingredients[0], "шт.")
	print("Мука:", ingredients[1], "ст.")
	print("Молоко:", ingredients[2], "л")
	print("Сахар:", ingredients[3], "ст. л.")
	print("Соль:", ingredients[4], "ч. л.")
	print("Растительное масло:", ingredients[5], "ст. л.")
	print()


def calc_ingredients(n_portions):
		ingredients = np.array([3, 1, 0.4, 1, 0.5, 1.5])
		return ingredients * n_portions

# Пример использования функции print_ingredients
ingredients_5 = calc_ingredients(5)
print_ingredients(ingredients_5)

ingredients_8 = calc_ingredients(8)
print_ingredients(ingredients_8)

ingredients_10 = calc_ingredients(10)
print_ingredients(ingredients_10)
# Out:
# Яйца: 15.0 шт.
# Мука: 5.0 ст.
# Молоко: 2.0 л
# Сахар: 5.0 ст. л.
# Соль: 2.5 ч. л.
# Растительное масло: 7.5 ст. л.
#
# Яйца: 24.0 шт.
# Мука: 8.0 ст.
# Молоко: 3.2 л
# Сахар: 8.0 ст. л.
# Соль: 4.0 ч. л.
# Растительное масло: 12.0 ст. л.
#
# Яйца: 30.0 шт.
# Мука: 10.0 ст.
# Молоко: 4.0 л
# Сахар: 10.0 ст. л.
# Соль: 5.0 ч. л.
# Растительное масло: 15.0 ст. л.
