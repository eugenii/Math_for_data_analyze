# %%
# Контрлльная 2
import numpy as np
from matplotlib import pyplot as plt



def f(x):
    return x ** 4 + 3 * x ** 3 - 9 * x ** 2 - 23 * x - 12

x = np.arange(-4, 3, 0.1)

result = f(x)
y = f(x)
plt.plot(x, y)

print(80)
plt.grid()
# Out:
# 80

# %% [markdown]
# Задача 2
# Оцените, как стоимость набора конструктора «Олег» зависит от количества деталек в нём.
# Номер набора	Количество деталей	Цена	Год	Уникальных деталек
# 1	109.0	3.99	2020	6.0
# 2	109.0	3.99	2020	6.0
# 3	52.0	4.99	2020	28.0
# ...	...	...	...	...
# Точками (plt.scatter) отметьте значения цены и количества деталей для всех наборов.
# Подберите коэффициенты прямой (полинома первой степени), которые описывают данную зависимость цены от количества деталей в наборе.   Постройте график найденной прямой. Для этого используйте plt.plot и
# x
# x-координаты точек из набора данных.
# Выведите коэффициенты найденной прямой. Первый коэффициент соответствует тому, на сколько в среднем увеличивается цена при добавлении одной детали к набору.

# %%
# 2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Считывание данных. В результате data - NumPy массив.
data = pd.read_csv('https://code.s3.yandex.net/Math/datasets/oleg_float.csv', index_col=0)
data = data.values.astype(float)
x = data[:, 1]
y = data[:, 2]
coefs_data = np.polyfit(x, y, 1)
poly_data = np.poly1d(coefs_data)
print(coefs_data)
plt.scatter(x, y)
plt.plot(x, poly_data(x))
# Out:
# [ 0.08164673 11.05513868]

# %% [markdown]
# ### Контрольная 2

# %%
import numpy as np
def f(x):
    return abs(2 - abs(4 - abs(x - 1) ** 2))

x = np.arange(-3, 5, 0.05)

y = f(x)

plt.plot(x, y)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Чтение данных. data - NumPy массив с 7-ю столбцами.
vals = pd.read_csv('https://code.s3.yandex.net/Math/datasets/auto-mpg.csv').to_numpy()

y = vals[:, 0:]
x = vals[:, 4:]

plt.xscale('log')
plt.yscale('log')
plot = plt.scatter(x, y, c = vals[:, 1:])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 13
#      11 plt.xscale('log')
#      12 plt.yscale('log')
# ---> 13 plot = plt.scatter(x, y, c = vals[:, 1:])
#      14 plt.show()
#
# File d:\work\projects\Math_for_data_analyze\venv\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...
