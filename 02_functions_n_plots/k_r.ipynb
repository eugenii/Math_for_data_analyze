# %%
# Контрлльная 2
import numpy as np
from matplotlib import pyplot as plt



def f(x):
    return x ** 4 + 3 * x ** 3 - 9 * x ** 2 - 23 * x - 2


# Для построения графика
x = np.arange([-4, 3, 0.1])
print(x)

# y = f(x)
# plt.plot(x, y)

# print(80)
# plt.grid()
